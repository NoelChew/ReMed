# %%
import folium
import pandas as pd
from ipywidgets import widgets, interact
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
# Create text widget for output
output_slider_variable = widgets.Text()

# Display output variable in text box
output_slider_variable

monthOffset = 1

# Define function to bind value of the input to the output variable 
def f(x):
    global monthOffset
    monthOffset = x
    #output_slider_variable.value = str(x)
    #print (output_slider_variable.value)
    # Create and output new int variable with value of slider

print ("Months left Expiring")
# Create input slider with default value = 10  
interact(f, x=widgets.IntSlider(min=1,max=12,step=1,value=2));
#interact(f, x=10)


#new_variable = int(output_slider_variable.value)
#print new_variable


drugs={'Ibuprofen':'Ibuprofen','Paracetamol':'Paracetamol'}

def select_drug(drug):
    print ("Selected " + str(drugs[drug]) + " Expiring in " + str(months) + " Months.")

scW = widgets.Select(options=drugs.keys())
#init = scW.value
widgets.interactive(select_drug, drug=scW)
# Out:
# Selected Paracetamol Expiring in 7 Months.

# %%
# Let Folium determine the scale.
#map = folium.Map(location=[48, -102], zoom_start=3)

#3.154205, 101.713112
map = folium.Map(location=[3.154205, 101.713112],
                   zoom_start=13)

medicine = pd.read_csv("data/remed2.csv")

#folium.RegularPolygonMarker(
#    [3.154205, 101.713112],
#    popup='KLCC',
#    fill_color='#132b5e',
#    number_of_sides=3,
#    radius=10
#    ).add_to(map)


#folium.CircleMarker([3.154205, 101.723112],
#                    radius=500,
#                    popup='KLCC Region',
#                    color='#3186cc',
#                    fill_color='#3186cc',
#                   ).add_to(map)

marker_cluster = folium.MarkerCluster("Medicine Cluster").add_to(map)

#MAX_RECORDS = 1000
 
#for each in medicine[0:MAX_RECORDS].iterrows():
for each in medicine.iterrows():
    date_object = datetime.strptime(each[1]['date_time'], '%b %Y')
    if date_object < datetime.today()+ relativedelta(months=monthOffset):
        folium.Marker([each[1]['lat'],each[1]['lng']], popup="Medicine Cluster").add_to(marker_cluster)



#folium.Marker([3.134105, 101.713112], popup="Medicine Cluster").add_to(marker_cluster)
#folium.Marker([3.134105, 101.723112], popup="Medicine Cluster2").add_to(marker_cluster)
#folium.Marker([3.134105, 101.733112], popup="Medicine Cluster3").add_to(marker_cluster)
#folium.Marker([3.134105, 101.743112], popup="Medicine Cluster4").add_to(marker_cluster)


map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
